# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,20)

# %%
fig, ax = plt.subplots(2,2)
# read the image

im_tissueHE = plt.imread('data/HE_merged/TCGA-18-5592-01Z-00-DX1/Image.jpg')

ax[0,0].imshow(im_tissueHE)

im_an = plt.imread('data/HE_merged/TCGA-18-5592-01Z-00-DX1/Image.tif')
ax[0,1].imshow(im_an, cmap='gray')

im_tissueHE = plt.imread('data/HE_merged/TCGA-18-5592-01Z-00-DX1/Image.jpg')

ax[1,0].imshow(im_tissueHE[10:120,10:120])

im_an = plt.imread('data/HE_merged/TCGA-18-5592-01Z-00-DX1/Image.tif')
ax[1,1].imshow(im_an[10:120,10:120], cmap='gray')

# %%
fig, ax = plt.subplots(3,2)
# read the image
im_tissue = plt.imread('data/IHC_Ki67/F VIS Databases Nuclei segmentation Ki67 ECP-002 002-020303 Ki67 - 2017-01-19 13_45_12 Image wss/'
                       +'OriginalImage_0.tif')
# show the image
ax[0,0].imshow(im_tissue)


im_Label = plt.imread('data/IHC_Ki67/F VIS Databases Nuclei segmentation Ki67 ECP-002 002-020303 Ki67 - 2017-01-19 13_45_12 Image wss/LabelImage_0.tif')
ax[1,0].imshow(im_Label, cmap='gray')

im_ROI = plt.imread('data/IHC_Ki67/F VIS Databases Nuclei segmentation Ki67 ECP-002 002-020303 Ki67 - 2017-01-19 13_45_12 Image wss/ROIImage_0.tif')
ax[0,1].imshow(im_ROI, cmap='gray')

ax[1,1].imshow(im_Label[:,:,None]*200+im_tissue, cmap='gray')

# Zoomed in on the upper left corner 
im_Label = plt.imread('data/IHC_Ki67/F VIS Databases Nuclei segmentation Ki67 ECP-002 002-020303 Ki67 - 2017-01-19 13_45_12 Image wss/LabelImage_0.tif')
ax[2,0].imshow(im_Label[10:120,10:120], cmap='gray')

ax[2,1].imshow(im_tissue[10:120,10:120], cmap='gray')

# %%
# a = [[[250,0,250],[250,100,250],[250,0,250]],
#      [[250,0,250],[250,100,250],[250,0,250]],
#      [[250,0,250],[0,0,0],[250,0,250]]]
# x, y, z = (np.array(a) > [0,0,0]).nonzero()
# print(x.shape,y.shape,z.shape)
# vals = im_tissue[x, y, z]
# print(vals)
